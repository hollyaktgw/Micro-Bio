# %%
# %matplotlib inline
import mahotas as mh
import numpy as np
from matplotlib import pyplot as plt
#from IPython.html.widgets import interact, fixed
plt.rcParams['figure.figsize'] = (10.0, 8.0) # 10 x 8 inches
plt.gray()

# %%
path= ('C:/Users/holly/OneDrive/Bureau/Internship/Dataset')

# %%
dna = mh.demos.load('nuclear')
print(dna.shape)
dna = dna.max(axis=2)
print(dna.shape)
plt.imshow(dna)
# Out:
# (1024, 1344, 3)
# (1024, 1344)

# %%
T_mean = dna.mean()
print(T_mean)
plt.imshow(dna > T_mean)
# Out:
# 27.490094866071427
